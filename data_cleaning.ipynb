# %% [markdown]
# ### Data cleaning Harry potter

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# load in the data
characters = pd.read_csv('data/Characters.csv', sep=';')
potions = pd.read_csv('data/Potions.csv', sep=';')
spells = pd.read_csv('data/Spells.csv', sep=';')

# %% [markdown]
# ### Data cleaning of the characters csv

# %%
characters.head()
# Out:
#    Id                                     Name  Gender  \
# 0   1                       Harry James Potter    Male
# 1   2                    Ronald Bilius Weasley    Male
# 2   3                    Hermione Jean Granger  Female
# 3   4  Albus Percival Wulfric Brian Dumbledore    Male
# 4   5                            Rubeus Hagrid    Male
#
#                                                  Job       House  \
# 0                                            Student  Gryffindor
# 1                                            Student  Gryffindor
# 2                                            Student  Gryffindor
# 3                                         Headmaster  Gryffindor
# 4  Keeper of Keys and Grounds | Professor of Care...  Gryffindor
#
#                                  Wand              Patronus  \
# 0         11"  Holly  phoenix feather                  Stag
# 1          12" Ash unicorn tail hair   Jack Russell terrier
# ...

# %%
characters.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            140 non-null    int64
#  1   Name          140 non-null    str
#  2   Gender        139 non-null    str
#  3   Job           121 non-null    str
#  4   House         101 non-null    str
#  5   Wand          132 non-null    str
#  6   Patronus      123 non-null    str
#  7   Species       140 non-null    str
#  8   Blood status  123 non-null    str
#  9   Hair colour   123 non-null    str
#  10  Eye colour    86 non-null     str
#  11  Loyalty       89 non-null     str
#  12  Skills        113 non-null    str
#  13  Birth         127 non-null    str
#  14  Death         42 non-null     str
# dtypes: int64(1), str(14)
# memory usage: 16.5 KB

# %% [markdown]
# Alla är har datatypen strings,

# %%
characters.tail()
# Out:
#       Id                      Name  Gender  \
# 135  136  Wilhelmina Grubbly-Plank  Female
# 136  137           Fenrir Greyback    Male
# 137  138       Gellert Grindelwald    Male
# 138  139                     Dobby    Male
# 139  140                  Kreacher    Male
#
#                                                    Job House  \
# 135  Substitute professor of Care of Magical Creatu...   NaN
# 136                                                NaN   NaN
# 137           Revolutionary leader(c. 1920s[6] – 1945)   NaN
# 138  Malfoy family's house-elf (? - 1993),\nHogwart...   NaN
# 139  \nBlack family's house-elf (?-1996), \nHarry P...   NaN
#
#                                     Wand       Patronus    Species  \
# 135                              Unknown  Non-corporeal     Human
# 136                              Unknown            NaN   Werewolf
# 137  15", Elder, Thestral tail hair core            NaN     Human
# ...

# %%
characters.columns = characters.columns.str.strip().str.replace(' ', '_').str.lower() # make the column names more consistent and easier to work with
characters.head()
# Out:
#    id                                     name  gender  \
# 0   1                       Harry James Potter    Male
# 1   2                    Ronald Bilius Weasley    Male
# 2   3                    Hermione Jean Granger  Female
# 3   4  Albus Percival Wulfric Brian Dumbledore    Male
# 4   5                            Rubeus Hagrid    Male
#
#                                                  job       house  \
# 0                                            Student  Gryffindor
# 1                                            Student  Gryffindor
# 2                                            Student  Gryffindor
# 3                                         Headmaster  Gryffindor
# 4  Keeper of Keys and Grounds | Professor of Care...  Gryffindor
#
#                                  wand              patronus  \
# 0         11"  Holly  phoenix feather                  Stag
# 1          12" Ash unicorn tail hair   Jack Russell terrier
# ...

# %%
characters.value_counts()
# Out:
# id  name                                     gender  job                                          house       wand                               patronus           species   blood_status  hair_colour                    eye_colour  loyalty                                                                                skills                                                                 birth                              death
# 4   Albus Percival Wulfric Brian Dumbledore  Male    Headmaster                                   Gryffindor  15" Elder Thestral tail hair core  Phoenix            Human     Half-blood    Silver| formerly auburn        Blue        Dumbledore's Army | Order of the Phoenix | Hogwarts School of Witchcraft and Wizardry  Considered by many to be one of the most powerful wizards of his time  Late August 1881                   30 June, 1997     1
# ...

# %%
characters.isnull().sum()
# Out:
# id               0
# name             0
# gender           1
# job             19
# house           39
# wand             8
# patronus        17
# species          0
# blood_status    17
# hair_colour     17
# eye_colour      54
# loyalty         51
# skills          27
# birth           13
# death           98
# dtype: int64

# %% [markdown]
# Drop columns that aren't relevant and have many missing values.

# %%
characters = characters.drop(columns=['hair_colour', 'eye_colour', 'wand']) # drop columns with too many missing values and not relevant us
characters.head()
# Out:
#    id                                     name  gender  \
# 0   1                       Harry James Potter    Male
# 1   2                    Ronald Bilius Weasley    Male
# 2   3                    Hermione Jean Granger  Female
# 3   4  Albus Percival Wulfric Brian Dumbledore    Male
# 4   5                            Rubeus Hagrid    Male
#
#                                                  job       house  \
# 0                                            Student  Gryffindor
# 1                                            Student  Gryffindor
# 2                                            Student  Gryffindor
# 3                                         Headmaster  Gryffindor
# 4  Keeper of Keys and Grounds | Professor of Care...  Gryffindor
#
#                patronus                species             blood_status  \
# 0                  Stag                  Human               Half-blood
# 1  Jack Russell terrier                  Human               Pure-blood
# ...
